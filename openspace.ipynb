# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage import io, measure

# %%
img = io.imread('sample.png')
plt.imshow(img)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
mask = cv2.inRange(hsv, (0, 100, 100), (10, 255, 255))

# %%
# below code not reviewed yetlow_yellow = np.array([36, 6, 34])
high_yellow = np.array([53, 100, 100])

# %%
mask = cv2.inRange(hsv, low_yellow, high_yellow)

# %%
img2 = cv2.bitwise_and(hsv, hsv, mask=mask)

# %%
# cv2.imshow('Hasil Segmentasi', mask)

# %%
# Display the segmentation result using matplotlib
plt.imshow(mask, cmap='gray')
plt.title('Hasil Segmentasi')
plt.axis('off')
plt.show()
